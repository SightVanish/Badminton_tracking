# %%
from google.colab import drive
drive.mount('/content/drive')
import os
from PIL import Image, ImageDraw
os.chdir('/content/drive/My Drive/TrackNet-Badminton')
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/My MacBook Air/TrackNet-Badminton

# %%
# !pip3 install opencv_python==3.4.2.17
# !pip3 install -r requirements.txt

import cv2
cv2.__version__
# Out:
# '3.4.2'

# %%
! python predict.py
# Out:
# 2021-10-13 08:42:44.605824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:44.615691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:44.616528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:44.617846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:44.618684: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:44.619522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:45.105715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:45.106695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:45.107483: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-13 08:42:45.108203: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-13 08:42:45.108270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10819 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7
# Load weights successfully
# Load csv file successfully
# Beginning predicting......
# 2021-10-13 08:42:46.756477: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-13 08:42:53.998910: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# .............................................................................................................................................................................................................................................................................................................................................................................................................==========================================================
# Number of true positive: 128
# Number of true negative: 50
# Number of false positive FP1: 10
# Number of false positive FP2: 4
# Number of false negative: 6
# Accuracy: 0.898989898989899
# Precision: 0.9014084507042254
# Recall: 0.9552238805970149
# Total Time: 41.75764870643616
# (ACC + Pre + Rec)/3: 0.9185407434303797
# Done......
